# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
constructed = pd.read_excel("ethiopa_constructed.xlsx")

# %%
# OUTCOME VARIABLES
# levlread
# levlwrit
# literate

# %%
oc_ethiopia = constructed[constructed['yc'] == 0]
rd1 = oc_ethiopia[oc_ethiopia['round'] == 1]
rd2 = oc_ethiopia[oc_ethiopia['round'] == 2]
rd3 = oc_ethiopia[oc_ethiopia['round'] == 3]
rd4 = oc_ethiopia[oc_ethiopia['round'] == 4]
rd5 = oc_ethiopia[oc_ethiopia['round'] == 5]

# %%
read_level = [x for x in constructed['levlread'] if type(x) == int]

# %%
read_level = [x for x in rd1['levlread'] if type(x) == int]
plt.hist(read_level, bins=4, range=(1,5))
plt.title('Distribution of Reading Level in Round 1')
# Out:
# Text(0.5, 1.0, 'Distribution of Reading Level in Round 1')

# %%
read_level = [x for x in rd2['levlread'] if type(x) == int]
plt.hist(read_level, bins=4, range=(1,5))
plt.title('Distribution of Reading Level in Round 2')
# Out:
# Text(0.5, 1.0, 'Distribution of Reading Level in Round 2')
